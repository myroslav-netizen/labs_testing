# %%
from datetime import datetime
name = "Myroslav"
location = "Ivano-Frankivsk"

print(f"{name} start programming at {datetime.now()}. {location} is the best city!")
# Out:
# Myroslav start programming at 2025-12-17 19:11:22.440896. Ivano-Frankivsk is the best city!

# %% [markdown]
# # Моя перша програма
